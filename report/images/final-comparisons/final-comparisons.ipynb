# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','..','..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['baseline', 'selfatt', 'mha', 'cbam']
rids1 = ['8da960ad489b42fc8594b98d6daffc86', 'e54b50f28b714171a6fdda483f901d9f', 'f5b8adbb257742839d9eaaf23b1274fd', 
         '764cca118f004e40b0954a0068da8793']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_err'])
plt1.savefig('model-comparisons-train-err.png', dpi=300)

# %%
mods = ['baseline', 'selfatt', 'mha', 'cbam']
rids1 = ['8da960ad489b42fc8594b98d6daffc86', 'e54b50f28b714171a6fdda483f901d9f', 'f5b8adbb257742839d9eaaf23b1274fd', 
         '764cca118f004e40b0954a0068da8793']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['test_err'])
plt1.savefig('model-comparisons-test-err.png', dpi=300)

# %%
mods = ['baseline', 'selfatt', 'mha', 'cbam']
rids1 = ['8da960ad489b42fc8594b98d6daffc86', 'e54b50f28b714171a6fdda483f901d9f', 'f5b8adbb257742839d9eaaf23b1274fd', 
         '764cca118f004e40b0954a0068da8793']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_loss'])
plt1.savefig('losses.png', dpi=300)
