# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','..','..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['selfatt']
rids1 = ['e424cebd75384e3e85c854098d60f3d2']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_loss', 'valid_loss'])
plt1.savefig('selfatt-adam.png', dpi=300)

# %%
mods = ['cbam']
rids1 = ['63d2a0913fb8432abd45f92446950e0b']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_loss', 'valid_loss'])
plt1.savefig('cbam-adam.png', dpi=300)

# %%
mods = ['baseline']
rids1 = ['e05ffb624c7f4f8cb34785e175f79a94']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_loss', 'valid_loss'])
plt1.savefig('baseline-sgd.png', dpi=300)

# %%
mods = ['selfatt', 'multihead att', 'cbam', 'baseline']
rids1 = ['e424cebd75384e3e85c854098d60f3d2', '64b2f1d30ba9435c9d388ffa9de05176','63d2a0913fb8432abd45f92446950e0b', 'e05ffb624c7f4f8cb34785e175f79a94']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title=None, metric_keys=['train_loss'], error=False)
plt1.savefig('adam.png', dpi=300)
