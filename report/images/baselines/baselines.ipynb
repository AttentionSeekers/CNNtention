# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','..','..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['cifar-10']
rids1 = ['8da960ad489b42fc8594b98d6daffc86']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title='ResNet-20 CIFAR-10 Baseline', metric_keys=['train_err', 'test_err'])
plt1.savefig('baseline-cifar.png', dpi=300)

# %%
mods = ['mnist']
rids1 = ['08ef1e5e2ca0421ebad1f90a4e9fad48']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot_two_metrics(title='ResNet-20 MNIST Baseline', metric_keys=['train_err', 'test_err'])
plt1.savefig('baseline-mnist.png', dpi=300)
