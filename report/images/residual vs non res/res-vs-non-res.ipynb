# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','..','..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['selfatt-resnet-residual']
rids1 = ['75e82f1561db41bb8e25a72bc40ae111']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot(title='Stable training on Residual SelfAttention Augments')
plt1.savefig('res-self-att-resnet.png', dpi=300)

# %%
mods = ['selfatt-resnet-non-residual']
rids = ['0f305d5c07774dd9b1925ec7416fbc52']
plotter = MLFlowPlotter(mods, rids, metric_key='train_loss')
plt1 = plotter.make_plot(title='Unstable training on Non-Residual SelfAttention Augments')
plt1.savefig('non-res-self-att-resnet.png', dpi=300)
