# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..','..','..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['selfatt-weighted', 'selfatt-unweighted']
rids1 = ['e424cebd75384e3e85c854098d60f3d2', '30fc528b2d954833becdd40579484db2']
plotter = MLFlowPlotter(mods, rids1, metric_key='train_loss')
plt1 = plotter.make_plot(title=None)
plt1.savefig('selfatt-weight-unweight-train-loss.png', dpi=300)

# %%
mods = ['selfatt-weighted', 'selfatt-unweighted']
rids1 = ['e424cebd75384e3e85c854098d60f3d2', '30fc528b2d954833becdd40579484db2']
plotter = MLFlowPlotter(mods, rids1, metric_key='valid_loss')
plt1 = plotter.make_plot(title=None)
plt1.savefig('selfatt-weight-unweight-valid-loss.png', dpi=300)
