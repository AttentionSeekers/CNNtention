# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import sys, os
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
mods = ['selfatt-resnet']
rids = ['0f305d5c07774dd9b1925ec7416fbc52']
plotter = MLFlowPlotter(mods, rids, metric_key='train_loss')
plt1 = plotter.make_plot(title='Unstable training on Non-Residual SelfAttention Resnet')
plt1.savefig('non-res-self-att-resnet.png', dpi=300)

# %%
models = ['baseline', 'selfatt-resnet', 'multihead-att']
runids = ['8da960ad489b42fc8594b98d6daffc86', 'e54b50f28b714171a6fdda483f901d9f', 'f5b8adbb257742839d9eaaf23b1274fd']
plotter = MLFlowPlotter(model_names=models, 
                        runids=runids, 
                        metric_key='test_err')

# %%
plotter.make_plot()

# %%
plotter.make_plot(metric_key='train_loss')
