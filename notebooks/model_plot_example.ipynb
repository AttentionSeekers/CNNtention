# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 2024-12-09 10:00:58 Monday

@author: Nikhil Kapila
"""

import torch, torchvision, mlflow, sys, os
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),'..')))
from utils.mlflow_plotter import MLFlowPlotter

# %%
# models = ['cbamresnet', 'selfatt-resnet', 'baseline']
# runids = ['63d2a0913fb8432abd45f92446950e0b', 'e54b50f28b714171a6fdda483f901d9f', '8da960ad489b42fc8594b98d6daffc86']
models = ['selfatt-resnet', 'baseline']
runids = ['e54b50f28b714171a6fdda483f901d9f', '8da960ad489b42fc8594b98d6daffc86']
plotter = MLFlowPlotter(model_names=models, 
                        runids=runids, 
                        metric_key='test_err')

# %%
plotter.make_plot()
