# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/cs7643
import sys
sys.path.append('/content/drive/MyDrive/cs7643')
# !pip install mlflow skorch
# !pip install Ipython --upgrade
# %cd /content/drive/MyDrive/cs7643
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'Copy of run3.ipynb'	 mlruns		        plots	      run2.ipynb
#  data			 models		        __pycache__   run3.ipynb
#  experiment_configs.py	 pipeline_template.py   run1.ipynb
# ...
# /content/drive/MyDrive/cs7643

# %%
# %ls
# Out:
# 'Copy of run3.ipynb'     mlruns/                plots/         run2.ipynb
#  data/                   models/                __pycache__/   run3.ipynb
#  experiment_configs.py   pipeline_template.py   run1.ipynb

# %%
import pipeline_template
import mlflow
from experiment_configs import configs
mlflow.set_tracking_uri('file:/content/drive/MyDrive/cs7643/mlruns')

# %%
# config = configs['cifar10_resnet20_multi_head_att']()
# print(config.model_config.model)
# config.model_config.model.__class__.__name__

# %%
pipeline_template.main('cifar10_resnet20_multi_head_att', True)
# pipeline_template.main('debug_config')
# Out:
# WARNING:root:Experiment ID mismatch for exp old998492728198223474. ID recorded as '998492728198223474' in meta data. Experiment will be ignored.
# NoneType: None
# === Model Details ===
# ResnetMultiHeadAtt(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (layer1): Sequential(
#     (0): OriginalBasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#     )
#     (1): OriginalBasicBlock(
# ...
